# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://wuzzuf.net/search/jobs/?q=ai+engineer&a=hpb"

# %%
site = requests.get(url)
site
# Out:
# <Response [200]>

# %%
website = requests.get("https://wuzzuf.net/search/jobs/?q=ai+engineer&a=hpb").text # website link ( URL ) 
website
# Out:
# '<!DOCTYPE html>\n<html lang="en" translate="no">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, shrink-to-fit=no">\n    <meta http-equiv="expires" content="Thu Dec 08 2022 18:30:44 GMT+0200" />\n\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate">\n    <meta name="googlebot" content="notranslate">\n    <title data-react-helmet="true">Job Search | WUZZUF</title>\n\n<meta data-react-helmet="true" charset="utf-8"/><meta data-react-helmet="true" name="description" content="Searching for jobs in Egypt? Wuzzuf helps you in your online job search to find Jobs in Egypt and Middle East. Choose the right job using our online recruitment services."/><meta data-react-helmet="true" name="keywords" content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexandria, employme
# ...

# %%
type(website)
# Out:
# str

# %%
website = BeautifulSoup(website, "lxml")
website
# Out:
# <!DOCTYPE html>
# <html lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-react-helmet="true">Job Search | WUZZUF</title>
# ...

# %%
type(website)
# Out:
# bs4.BeautifulSoup

# %%
website.title
# Out:
# <title data-react-helmet="true">Job Search | WUZZUF</title>

# %%
job = website.find("div", class_ = "css-pkv5jc")
job
# Out:
# <div class="css-pkv5jc"><a href="https://wuzzuf.net/jobs/careers/Care-Dental-Egypt-27404" rel="noreferrer" target="_blank"><style data-emotion="css 17095x3">.css-17095x3{position:absolute;right:0;top:0;width:60px;height:60px;object-fit:contain;object-position:center center;}</style></a><style data-emotion="css laomuu">.css-laomuu{padding-right:60px;}</style><div class="css-laomuu"><style data-emotion="css m604qf">.css-m604qf{font-size:16px;font-weight:600;font-style:normal;letter-spacing:-0.4px;line-height:24px;color:#0055D9;margin:0;}</style><h2 class="css-m604qf"><style data-emotion="css o171kl">.css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}</style><a class="css-o171kl" href="https://wuzzuf.net/internship/XwXoHCEDJryd-AI-Data-Science-Python-Developer-Intern-Sequel-Solutions-Cairo-Egypt" rel="noreferrer" target="_blank">AI &amp; Data Science Python Developer Intern</a></h2><style data-emotion="css d7j1kk">.css-d7j1kk{margin-bottom:8px;overflow:hidden;t
# ...

# %%
jobtitle = job.find("a", class_ = "css-o171kl").text
jobtitle
# Out:
# 'AI & Data Science Python Developer Intern'

# %%
companyname= job.find("a", class_ ="css-17s97q8").text
companyname
# Out:
# 'Sequel Solutions -'

# %%
location = job.find("span", class_ = "css-5wys0k").text
location
# Out:
# 'Cairo, Egypt '

# %%
jobtype = job.find("span", class_= "css-1ve4b75 eoyjyou0").text
jobtype
# Out:
# 'Internship'

# %%
jobs = website.find_all("div", class_ = "css-pkv5jc")

for job in jobs: 
    jobtitle = job.find("a", class_ = "css-o171kl").text
    companyname= job.find("a", class_ ="css-17s97q8").text
    location = job.find("span", class_ = "css-5wys0k").text
    jobtype = job.find("span", class_= "css-1ve4b75 eoyjyou0").text
    
    print(jobtitle, companyname, location , jobtype)
# Out:
# AI & Data Science Python Developer Intern Sequel Solutions - Cairo, Egypt  Internship
# AI Engineer Ewa  - Cairo, Egypt  Full Time
# AI Web Developer Finding From Egy  - Smouha, Alexandria, Egypt  Full Time
# Senior AI Researcher Nahdet Misr Publishing Group - Mohandessin, Giza, Egypt  Full Time
# AI Software Engineer, Trilogy (Remote) - $100,000/year USD Crossover - Dubai, United Arab Emirates  Full Time
# Research Engineer Ewa  - Cairo, Egypt  Full Time
# AI Software Engineer, Skyvera (Remote) - $200,000/year USD Crossover - Cairo, Egypt  Full Time
# Full-stack Software Engineer (AI Applications) CharCentric - Cairo, Egypt  Freelance / Project
# Senior Python Developer Etisalat Egypt - Cairo, Egypt  Full Time
# AI/ Machine Learning Sr. Engineer MIGRATIONIT - Cairo, Egypt  Full Time
# Remote Machine Learning/AI Developer Scopic Software - Cairo, Egypt  Full Time
# Second Level Technical Support Engineer 3D Diagnostix - Maadi, Cairo, Egypt  Full Time
# ...

# %%
import csv

# %%
csvfile = open ('AIjobs.csv', 'w', encoding='utf-8')
writer = csv.writer(csvfile)

# %%
writer.writerow(['Job title', 'Company', 'location', 'job type'])
# Out:
# 37

# %%
jobs = website.find_all("div", class_ = "css-pkv5jc")

for job in jobs: 
    jobtitle = job.find("a", class_ = "css-o171kl").text
    companyname= job.find("a", class_ ="css-17s97q8").text
    location = job.find("span", class_ = "css-5wys0k").text
    jobtype = job.find("span", class_= "css-1ve4b75 eoyjyou0").text
    
    writer.writerow([jobtitle, companyname, location, jobtype ])
csvfile.close()

# %%
csvfile = open ('AIalljobs.csv', 'w', encoding='utf-8') # w = write into the file , general way of representing data 
writer = csv.writer(csvfile)
writer.writerow(['Job title', 'Company', 'location', 'job type'])
for i in range(3):
    if i == 0 : 
        url = "https://wuzzuf.net/search/jobs/?q=ai+engineer&a=hpb"
    else:
        url = f"https://wuzzuf.net/search/jobs/?a=hpb&q=ai%20engineer&start={i}"
    website = requests.get(url).text
    website = BeautifulSoup(website , "lxml")
    
    jobs = website.find_all("div", class_ = "css-pkv5jc")

    for job in jobs: 
        jobtitle = job.find("a", class_ = "css-o171kl").text
        companyname= job.find("a", class_ ="css-17s97q8").text
        location = job.find("span", class_ = "css-5wys0k").text
        jobtype = job.find("span", class_= "css-1ve4b75 eoyjyou0").text

        writer.writerow([jobtitle, companyname, location, jobtype ])
csvfile.close()
